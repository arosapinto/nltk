# %% [markdown]
# #### Libraries
#
#  -Camelot: extract tables in PDFs
#
#  -PyPDF2:  library for extracting text from PDFs where text is in a sequential or formatted manner i.e. in lines or forms
#
#  -PyMuPDF: extracting images from PDF, extracting texts from different shapes, making annotations, draw a bounded box around the texts along with the features of libraries like PyPDF2
#
#  -PDFMiner: is a tool for extracting information from PDF documents. Unlike other PDF-related tools, it focuses entirely on getting and analyzing text data
#
#  -Tabula-py: is a simple Python wrapper of tabula-java, which can read the table of PDF. You can read tables from PDF and convert into pandas’ DataFrame. tabula-py also enables you to convert a PDF file into CSV/TSV/JSON file
#
#  -Slate is wrapper Implementation of PDFMiner
#
#  -PDFQuery is a light wrapper around pdfminer, lxml and pyquery. It’s designed to reliably extract data from sets of PDFs with as little code as possible
#
#  -xpdf: Python wrapper for xpdf (currently just the “pdftotext” utility)

# %% [markdown]
# ### Camelot: doesn't work currently
#
# extract tables in PDFs

# %%
#!pip install camelot-py
#!pip install camelot-py[cv]
#import camelot
import camelot.io as camelot
from tabula import read_pdf
#!pip uninstall camelot
#pip uninstall camelot-py
#pip install camelot-py[cv]
#!pip install ghostscript

# %%
#!pip install ghostscript
import sys
import locale
import ctypes
from ctypes.util import find_library
import ghostscript
find_library("".join(("gsdll", str(ctypes.sizeof(ctypes.c_voidp) * 8), ".dll")))
# Out:
# ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\Test folder\nltk\extract pdf.ipynb Cell 5' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Test%20folder/nltk/extract%20pdf.ipynb#ch0000004?line=3'>4</a> import ctypes
#       <a href='vscode-notebook-cell:/c%3A/Test%20folder/nltk/extract%20pdf.ipynb#ch0000004?line=4'>5</a> from ctypes.util import find_library
# ----> <a href='vscode-notebook-cell:/c%3A/Test%20folder/nltk/extract%20pdf.ipynb#ch0000004?line=5'>6</a> import ghostscript
#       <a href='vscode-notebook-cell:/c%3A/Test%20folder/nltk/extract%20pdf.ipynb#ch0000004?line=6'>7</a> find_library("".join(("gsdll", str(ctypes.sizeof(ctypes.c_voidp) * 8), ".dll")))
#
# File c:\Users\APinto\anaconda3\envs\projeto_apspacy\lib\site-packages\ghostscript\__init__.py:32, in <module>
# ...

# %%
tables = camelot.read_pdf("C:\\Users\\APinto\\OneDrive\\Documentos\\certificates\\Receipt_305716_Two Impulse, Lda. - Sheet2.pdf")
tables
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Test folder\nltk\extract pdf.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Test%20folder/nltk/extract%20pdf.ipynb#ch0000005?line=0'>1</a> tables = camelot.read_pdf("C:\\Users\\APinto\\OneDrive\\Documentos\\certificates\\Receipt_305716_Two Impulse, Lda. - Sheet2.pdf")
#       <a href='vscode-notebook-cell:/c%3A/Test%20folder/nltk/extract%20pdf.ipynb#ch0000005?line=1'>2</a> tables
#
# NameError: name 'camelot' is not defined

# %%
tables.export("C:\\Users\\APinto\\OneDrive\\Documentos\\certificates\\Receipt_305716_Two Impulse, Lda. - Sheet2.csv", f='csv', compress=True) # json, excel, html, markdown, sqlite
tables[0]

tables[0].parsing_report

tables[0].to_excel('C:\\Users\\APinto\\OneDrive\\Documentos\\certificates\\new.xlsx') # to_json, to_excel, to_html, to_markdown, to_sqlite
tables[0].df # get a pandas DataFrame!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Test folder\nltk\extract pdf.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Test%20folder/nltk/extract%20pdf.ipynb#ch0000006?line=0'>1</a> tables.export("C:\\Users\\APinto\\OneDrive\\Documentos\\certificates\\Receipt_305716_Two Impulse, Lda. - Sheet2.csv", f='csv', compress=True) # json, excel, html, markdown, sqlite
#       <a href='vscode-notebook-cell:/c%3A/Test%20folder/nltk/extract%20pdf.ipynb#ch0000006?line=1'>2</a> tables[0]
#       <a href='vscode-notebook-cell:/c%3A/Test%20folder/nltk/extract%20pdf.ipynb#ch0000006?line=3'>4</a> tables[0].parsing_report
#
# NameError: name 'tables' is not defined

# %% [markdown]
# ### PyPDF2
#
# library for extracting text from PDFs where text is in a sequential or formatted manner i.e. in lines or forms

# %%
#pip install PyPDF2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing required modules 
import PyPDF2 
    
# creating a pdf file object 
pdfFileObj = open('C:\\Users\\APinto\\OneDrive\\Documentos\\pdfs cv\\carta despedimento.pdf', 'rb') 

# creating a pdf reader object 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj) 
    
# printing number of pages in pdf file 
print(pdfReader.numPages) 
    
# creating a page object 
pageObj = pdfReader.getPage(0)
print('Page type: {}'.format(str(type(pageObj))))

information = pdfReader.getDocumentInfo()
print(information)

# extracting text from page 
print("Texto: -->", pageObj.extractText())
# Out:
# 1
# Page type: <class 'PyPDF2.pdf.PageObject'>
# {'/Author': 'Pinto, Ana', '/Creator': 'Microsoft® Word for Microsoft 365', '/CreationDate': "D:20220106142514+00'00'", '/ModDate': "D:20220106142514+00'00'", '/Producer': 'Microsoft® Word for Microsoft 365'}
# Texto: --> An
# a Ro sa Almeida
# P into
#
# Ru
# a M i
# guelT
# o rga, Nº3 2 º
# DTO  Barreiro
# , Po rtugal
#
#
# AccentureTe chno lo gy  So lutio ns, S.A
#
#
#
#
#
#
#
# Exmo  Sr.D ireto r de Recurso s Hum ano s
#
#
#
#
#
#
#
# Amo reiras,To rre1 ,1 6 ºP iso
# t
#
# L isbo a,
#
#
#
#
#
#
#
# P o rtugal.
#
#
#
# Barreiro ,
# 6
#
# de Janeiro  de 20 22
#
# Assunto :
#
# Rescisão de Co ntrato  de Trabalho
#
#
# Exmo
# s. Senho res,
#
# Eu,
#
# Ana Ro sa Alm eida P into
# , com  o  CC
#
# 14 70 832 2
# , NIF
# 2 50 39 166 0
# , residente em
# Rua M iguel
# To rga Nº3 2ºD TO 2 83 0
# -
# 5 56  Barreiro
# ,
# v enho
#
# fo rmalmente,
#
# po r
# meio des
# t
# a carta
# ,
#
# co m unicar o
# m eu pedido de
#
# res
# c
# i
# s
# ão
# ...

# %%
text=''
for i in range(0,pdfReader.numPages):
    # creating a page object
    pageObj = pdfReader.getPage(i)
    # extracting text from page
    text=text+pageObj.extractText()
print(text)
# closing the pdf file object 
pdfFileObj.close()
# Out:
# An
# a Ro sa Almeida
# P into
#
# Ru
# a M i
# guelT
# o rga, Nº3 2 º
# DTO  Barreiro
# , Po rtugal
#
#
# AccentureTe chno lo gy  So lutio ns, S.A
#
#
#
#
#
#
#
# Exmo  Sr.D ireto r de Recurso s Hum ano s
#
#
#
#
#
#
#
# Amo reiras,To rre1 ,1 6 ºP iso
# t
#
# L isbo a,
#
#
#
#
#
#
#
# P o rtugal.
#
#
#
# Barreiro ,
# 6
#
# de Janeiro  de 20 22
#
# Assunto :
#
# Rescisão de Co ntrato  de Trabalho
#
#
# Exmo
# s. Senho res,
#
# Eu,
#
# Ana Ro sa Alm eida P into
# , com  o  CC
#
# 14 70 832 2
# , NIF
# 2 50 39 166 0
# , residente em
# Rua M iguel
# To rga Nº3 2ºD TO 2 83 0
# -
# 5 56  Barreiro
# ,
# v enho
#
# fo rmalmente,
#
# po r
# meio des
# t
# a carta
# ,
#
# co m unicar o
# m eu pedido de
#
# res
# c
# i
# s
# ão
#
# do co ntrato  de trabalho
# sem
# te rmo
# celebrado a
#
# 14
#
# de Janei
# ro  de
# 2 01 9
#
# com  a
# Accenture
#
# passando , a partir de ho je, a cumprir o perío do de av iso  prév io  de 6 0 dias
# (se ssenta dias)co nfo rm e disposto  no n.º1  do art.º
#
# ...

# %%
# creating a pdf file object 
pdfFileObj = open('C:\\Users\\APinto\\OneDrive\\Documentos\\pdfs cv\\BABOK Guide v3.pdf', 'rb') 

# creating a pdf reader object 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj) 
    
# printing number of pages in pdf file 
print(pdfReader.numPages) 
    
# creating a page object 
pageObj = pdfReader.getPage(20) 

information = pdfReader.getDocumentInfo()
print(information)

# extracting text from page 
print(pageObj.extractText()) 
# closing the pdf file object 
pdfFileObj.close()
# Out:
# 514
# {'/CreationDate': 'D:20191217161829', '/Creator': 'PDFium', '/Producer': 'PDFium'}
# 11
# Complimentary IIBA¨ Membe r Copy. Not for Distribution or Resale.
# 2
# Business Analysis Key Concepts
# TheBusinessAnalysisKeyConceptschapte
# ri n c l u d e s i n f o r m a t i o n t h a t p ro v i d e s a
# foundationfo rallothercontent,
#  c o n c e p t s ,  a n d  i d e a s  w i t h i n  t h e
# BABO K
# ¨
#  G u i d e
# .
# It  p ro v id es  b u s in es s  an a ly s ts  w i th  a  b as ic  u n d e r s t a n d in g  o f t h e  c e n t r a l i d e a s
# necessary fo run derstand in g an dem ploying the
# BABOK
# ¨
#  G u i d e
# intheirdaily
# practiceo f bu sinessanalysis.
# Thischapter consists of:
# ¥
# BusinessAnalysisCore ConceptModelª(BACCMª)
# :definesa
# conceptualframework fo rthebu
# siness an alysis profession.
# ¥
# KeyTe rms
# :provides definitionsof essentialconcepts,whichare
# high ligh ted b ecau seof
# th e i r  i m p o r t a n c e  t o  t h e
# BABO K
# ¨
# ...

# %% [markdown]
# ### PDFMiner
#
# is a tool for extracting information from PDF documents. Unlike other PDF-related tools, it focuses entirely on getting and analyzing text data
#
# -Pure Python (3.6 or above).
#
# -Supports PDF-1.7. (well, almost)
#
# -Obtains the exact location of text as well as other layout information (fonts, etc.).
#
# -Performs automatic layout analysis.
#
# -Can convert PDF into other formats (HTML/XML).
#
# -Can extract an outline (TOC).
#
# -Can extract tagged contents.
#
# -Supports basic encryption (RC4 and AES).
#
# -Supports various font types (Type1, TrueType, Type3, and CID).
#
# -Supports CJK languages and vertical writing scripts.
#
# -Has an extensible PDF parser that can be used for other purposes.

# %%
#!pip install pdfminer.six
#!python -m pdfminer.six validate
from pdfminer.high_level import extract_text
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO

# %%
def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

# %%
#convert_pdf_to_txt('C:\\Users\\APinto\\OneDrive\\Documentos\\pdfs cv\\BABOK Guide v3.pdf')

# %%
from pdfminer.layout import LAParams
from pdfminer.converter import PDFPageAggregator
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.layout import LTTextBoxHorizontal

def parsedocument(document):
    # convert all horizontal text into a lines list (one entry per line)
    # document is a file stream

    lines = []
    rsrcmgr = PDFResourceManager()
    laparams = LAParams()
    device = PDFPageAggregator(rsrcmgr, laparams=laparams)
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    for page in PDFPage.get_pages(document):
            interpreter.process_page(page)
            layout = device.get_result()
            for element in layout:
                if isinstance(element, LTTextBoxHorizontal):
                    lines.extend(element.get_text().splitlines())
    return lines

# %%
fh = open('C:\\Users\\APinto\\OneDrive\\Documentos\\pdfs cv\\carta despedimento.pdf', 'rb')
parsedocument(fh)
# Out:
# ['Ana Rosa Almeida Pinto ',
#  'Rua Miguel Torga, Nº3 2ºDTO Barreiro, Portugal ',
#  'Accenture Technology Solutions, S.A ',
#  'Exmo Sr. Diretor de Recursos Humanos ',
#  'Amoreiras, Torre 1, 16ºPiso – Lisboa, ',
#  'Portugal. ',
#  'Barreiro, 6 de Janeiro de 2022 ',
#  'Assunto: Rescisão de Contrato de Trabalho ',
#  'Exmos. Senhores, ',
#  'Eu,  Ana  Rosa  Almeida  Pinto,  com  o  CC  14708322,  NIF  250391660,  residente  em  Rua  Miguel ',
#  'Torga Nº3 2ºDTO 2830-556 Barreiro, venho formalmente, por meio desta carta, comunicar o ',
#  'meu pedido de rescisão do contrato de trabalho sem termo celebrado a 14 de Janeiro de 2019 ',
#  'com  a  Accenture  passando,  a  partir  de  hoje,  a  cumprir  o  período  de  aviso  prévio  de 60  dias ',
#  '(sessenta dias) conforme disposto no n.º 1 do art.º 400.º do Código do Trabalho. ',
#  'Solicito autorização para que, durante o período de aviso prévio, me seja permitido usufruir de ',
# ...

# %%
import io

from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage


def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos = set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages,
                                  password=password,
                                  caching=caching,
                                  check_extractable=True):
        interpreter.process_page(page)



    fp.close()
    device.close()
    text = retstr.getvalue()
    retstr.close()
    return text

# %%
convert_pdf_to_txt('C:\\Users\\APinto\\OneDrive\\Documentos\\pdfs cv\\carta despedimento.pdf')
# Out:
# 'Ana Rosa Almeida Pinto \n\nRua Miguel Torga, Nº3 2ºDTO Barreiro, Portugal \n\nAccenture Technology Solutions, S.A \n\nExmo Sr. Diretor de Recursos Humanos \n\nAmoreiras, Torre 1, 16ºPiso – Lisboa, \n\nPortugal. \n\nBarreiro, 6 de Janeiro de 2022 \nAssunto: Rescisão de Contrato de Trabalho \n\nExmos. Senhores, \n\nEu,  Ana  Rosa  Almeida  Pinto,  com  o  CC  14708322,  NIF  250391660,  residente  em  Rua  Miguel \nTorga Nº3 2ºDTO 2830-556 Barreiro, venho formalmente, por meio desta carta, comunicar o \nmeu pedido de rescisão do contrato de trabalho sem termo celebrado a 14 de Janeiro de 2019 \ncom  a  Accenture  passando,  a  partir  de  hoje,  a  cumprir  o  período  de  aviso  prévio  de 60  dias \n(sessenta dias) conforme disposto no n.º 1 do art.º 400.º do Código do Trabalho. \n\nSolicito autorização para que, durante o período de aviso prévio, me seja permitido usufruir de \n7 dias de férias, de 23 de Fevereiro a 7 de Março. Sendo o último dia de trabalho efetivo a 22 de \nFever
# ...

# %% [markdown]
# ### Tabula-py

# %%
##Reading the Table data from pdf
#!pip install tabula-py

# %%
import tabula
# readinf the PDF file that contain Table Data
# you can find find the pdf file with complete code in below
# read_pdf will save the pdf table into Pandas Dataframe
df = tabula.read_pdf("C:\\Users\\APinto\\OneDrive\\Documentos\\certificates\\Receipt_305716_Two Impulse, Lda. - Sheet2.pdf", pages='all', multiple_tables=True)
# in order to print first 5 lines of Table
#
#df.head()
df
# Out:
# [                     Unnamed: 0        Date  Sale No.
#  0  600 Harrison St. – 3rd Floor  03/30/2022    305716,
#                                        Date Purchased  Item  Qty   Price  \
#  0  03/15/2022 2021 Natural Language Processing in...   NaN  1.0  €14.99
#  1                                         Net Amount   NaN  NaN  €12.19
#  2                                                Tax   NaN  NaN   €2.80
#  3                       We appreciate your business!   NaN  NaN   TOTAL
#
#     Amount Paid Unnamed: 0
#  0          NaN     €14.99
#  1          NaN        NaN
#  2          NaN        NaN
#  3          NaN     €14.99  ]

# %%
#If you Pdf file contain Multiple Table
df = tabula.read_pdf("C:\\Users\\APinto\\OneDrive\\Documentos\\certificates\\Receipt_305716_Two Impulse, Lda. - Sheet2.pdf", multiple_tables=True, pages=1)

# %%
#you can extract Information from the specific part of any specific page of PDF
tabula.read_pdf("C:\\Users\\APinto\\OneDrive\\Documentos\\certificates\\Receipt_305716_Two Impulse, Lda. - Sheet2.pdf", area=(126,149,212,462), pages=1)

# According to tabula-java wiki, there is a explain how to specify the area: https://github.com/tabulapdf/tabula-java/
# wiki/Using-the-command-line-tabula-extractor-tool#grab-coordinates-of-the-table-you-want
# For example, using macOS’s preview
# Out:
# [Empty DataFrame
#  Columns: [ino Fonseca, Lote 1A, 7005-345 Évora]
#  Index: []]

# %%
#If you want the output into JSON Format
tabula.read_pdf("C:\\Users\\APinto\\OneDrive\\Documentos\\certificates\\Receipt_305716_Two Impulse, Lda. - Sheet2.pdf", output_format="json")
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# [{'extraction_method': 'stream',
#   'top': 76.0,
#   'left': 52.0,
#   'width': 509.0,
#   'height': 28.0,
#   'right': 561.0,
#   'bottom': 104.0,
#   'data': [[{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 84.72,
#      'left': 461.23,
#      'width': 18.18218994140625,
#      'height': 3.700000047683716,
#      'text': 'Date'},
#     {'top': 84.72,
#      'left': 514.73,
#      'width': 31.07001495361328,
#      'height': 3.700000047683716,
#      'text': 'Sale No.'}],
#    [{'top': 96.85,
#      'left': 52.05,
#      'width': 106.15219116210938,
#      'height': 3.700000047683716,
#      'text': '600 Harrison St. – 3rd Floor'},
#     {'top': 96.85,
#      'left': 449.65,
#      'width': 40.532196044921875,
#      'height': 3.700000047683716,
#      'text': '03/30/2022'},
#     {'top': 96.85,
#      'left': 516.93,
#      'width': 26.299983978271484,
# ...

# %%
### Export Pdf into Excel
tabula.convert_into("C:\\Users\\APinto\\OneDrive\\Documentos\\certificates\\Receipt_305716_Two Impulse, Lda. - Sheet2.pdf", "C:\\Users\\APinto\\OneDrive\\Documentos\\certificates\\offense_testing.xlsx", output_format="csv")
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.

# %% [markdown]
# ### PyMuPDF
#
# extracting images from PDF, extracting texts from different shapes, making annotations, draw a bounded box around the texts along with the features of libraries like PyPDF2
#
# For all supported document types (i.e. including images) you can:
# - decrypt the document
# - access meta information, links and bookmarks
# - render pages in raster formats (PNG and some others), or the vector format SVG
# - search for text
# - extract text and images
# - convert to other formats: PDF, (X)HTML, XML, JSON, text
# - do OCR (Optical Character Recognition) if Tesseract is installed

# %%
#!pip install pymupdf

# %%
## PyMuPDF
   # good for when we want to collect text that is always in the same place

import fitz
import pandas as pd 
doc = fitz.open('C:\\Users\\APinto\\OneDrive\\Documentos\\pdfs cv\\BABOK Guide v3.pdf')
doc
npages = doc.page_count
npages
toc = doc.get_toc() #table of contents
print ("TOC is", toc)
for t in toc: print(t) 
meta_data = doc.metadata
print ("meta_data is", meta_data)
# page1 = doc[0]
# words = page1.get_text("words")
# page1
# words

# Then the object of the PDF file is created and stored in doc and 1st page of pdf is stored on page1. page.get_text() extracts all the words of page 1. Each word consists of a tuple with 8 elements.
# In words variable, the First 4 elements represent the coordinates of the word, 5th element is the word itself, 6th,7th, 8th elements are block, line, word numbers respectively.
# Out:
# TOC is []
# meta_data is {'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'creator': 'PDFium', 'producer': 'PDFium', 'creationDate': 'D:20191217161829', 'modDate': '', 'trapped': '', 'encryption': None}

# %%
# extract_text for each page
for pageNumber, page in enumerate(doc.pages(), start = 1):
    text = page.get_text()
    txt = open(f'report_Page_{pageNumber}', 'a')
    txt.write(text)
    txt.close()

# %%
# # extract images
# # for pageNumber, page in enumerate(doc.pages(:10), start = 1):
# #     for imgNumber, img in enumerate(page.get_Image(), start = 1):
# #         xref = img[0]
# #         pix = fitz.Pixmap(doc, xref)

# #         if pix.n > 4: #pix.n means bytes per pixel, higher than 4 is a bad image
# #             pix = fitz.Pixmap(fitz.csRGB, pix)
# #         pix.save(f'IMAGE_Page_{pageNumber}_{imgNumber}.png')

# %%
page = doc.load_page(20)  # loads page number 'pno' of the document (0-based)
page = doc[20]
page
# Out:
# page 20 of C:\Users\APinto\OneDrive\Documentos\pdfs cv\BABOK Guide v3.pdf

# %% [markdown]
# ### To use in pdf's with rectangules - https://www.analyticsvidhya.com/blog/2021/06/data-extraction-from-unstructured-pdfs/

# %%
# doc = fitz.open('C:\\Users\\APinto\\OneDrive\\Documentos\\pdfs cv\\IMG_20191209_0001.pdf')
# page1 = doc[0]
# words = page1.get_text("words")
# words


# ## Extract the coordinates of the first object
# first_annots=[]

# rec=page1.first_annot.rect

# rec

# #Information of words in first object is stored in mywords

# mywords = [w for w in words if fitz.Rect(w[:4]) in rec]

# ann= make_text(mywords)

# first_annots.append(ann)

# %%
# def make_text(words):

#     line_dict = {} 

#     words.sort(key=lambda w: w[0])

#     for w in words:  

#         y1 = round(w[3], 1)  

#         word = w[4] 

#         line = line_dict.get(y1, [])  

#         line.append(word)  

#         line_dict[y1] = line  

#     lines = list(line_dict.items())

#     lines.sort()  

#     return "n".join([" ".join(line[1]) for line in lines])

# %%
# for pageno in range(0,len(doc)-1):

#     page = doc[pageno]

#     words = page.get_text("words")

#     for annot in page.annots():

#         if annot!=None:

#             rec=annot.rect

#             mywords = [w for w in words if fitz.Rect(w[:4]) in rec]

#             ann= make_text(mywords)

#             all_annots.append(ann)

# %%
# #### Data Cleaning and Data Processing
# #Splitting to form column name and its values :

# cont=[]

# for i in range(0,len(all_annots)):

#     cont.append(all_annots[i].split('n',1))

# %%
# ## Removing unnecessary symbols *,#,:
# liss=[]

# for i in range(0,len(cont)):

#     lis=[]

#     for j in cont[i]:

#         j=j.replace('*','')

#         j=j.replace('#','')

#         j=j.replace(':','')

#         j=j.strip()
        
#         #print(j)

#         lis.append(j)

#     liss.append(lis)

# %%
# # Spliting into keys and values and removing spaces in the values which only contain digits :

# keys=[]

# values=[]

# for i in liss:

#     keys.append(i[0])

#     values.append(i[1])

# for i in range(0, len(values)):

#     for j in range(0,len(values[i])):

#         if values[i][j]>='A' and values[i][j]<='Z':

#             break            

#     if j==len(values[i])-1:
#        values[i]=values[i].replace(' ','')

# %%
# # Converting to dictionary :

# report=dict(zip(keys,values))
